# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cd c:/Users/tshankar/Desktop/Research/Data/Results/IROS24_Submission/JointH2RDir/
# Out:
# c:\Users\tshankar\Desktop\Research\Data\Results\IROS24_Submission\JointH2RDir

# %%
x = plt.imread("F2.png")

# %%
plt.imshow(x)

# %%
plt.imshow(x[200:,:300])

# %%
plt.imshow(x[:300,300:])
